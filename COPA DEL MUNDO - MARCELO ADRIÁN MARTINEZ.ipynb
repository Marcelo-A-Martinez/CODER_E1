# %%
# COPA DEL MUNDO

# %%
# ARCHIVO: world_cups

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\world_cups.csv', sep=',', header=0)
df
# Out:
#     Year  Host Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
# ARCHIVO: world_cup_matches

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\world_cup_matches.csv', sep=',', header=0)
df
# Out:
#       ID  Year        Date           Stage      Home Team  Home Goals  \
# 0      1  1930  1930-07-13     Group stage         France           4
# 1      2  1930  1930-07-13     Group stage  United States           3
# 2      3  1930  1930-07-14     Group stage     Yugoslavia           2
# 3      4  1930  1930-07-14     Group stage        Romania           3
# 4      5  1930  1930-07-15     Group stage      Argentina           1
# ..   ...   ...         ...             ...            ...         ...
# 895  896  2018  2018-07-07  Quarter-finals         Russia           2
# 896  897  2018  2018-07-10     Semi-finals         France           1
# 897  898  2018  2018-07-11     Semi-finals        Croatia           2
# 898  899  2018  2018-07-14     Third place        Belgium           2
# 899  900  2018  2018-07-15           Final         France           4
#
#      Away Goals Away Team                    Win Conditions  Host Team
# ...

# %%
# ARCHIVO: international_matches

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\international_matches.csv', sep=',', header=0)
df
# Out:
#           ID           Tournament        Date     Home Team  Home Goals  \
# 0          1             Friendly  1872-11-30      Scotland           0
# 1          2             Friendly  1873-03-08       England           4
# 2          3             Friendly  1874-03-07      Scotland           2
# 3          4             Friendly  1875-03-06       England           2
# 4          5             Friendly  1876-03-04      Scotland           3
# ...      ...                  ...         ...           ...         ...
# 17764  17765             Friendly  2022-09-27         Qatar           2
# 17765  17766             Friendly  2022-09-27  Saudi Arabia           0
# 17766  17767  UEFA Nations League  2022-09-27      Portugal           0
# 17767  17768  UEFA Nations League  2022-09-27   Switzerland           2
# 17768  17769  UEFA Nations League  2022-09-27        Norway           0
#
#        Away Goals       Away Team Win Conditions  Home Stadium
# ...

# %%
# ARCHIVO: _2022_world_cup_squads

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\_2022_world_cup_squads.csv', sep=',', header=0, encoding='latin-1')
df
# Out:
#       ID     Team    Position               Player  Age  Caps  Goals  \
# 0      1  Ecuador  Goalkeeper      Hernán Galíndez   35    12      0
# 1      2  Ecuador    Defender         Félix Torres   25    17      2
# 2      3  Ecuador    Defender       Piero Hincapié   20    21      1
# 3      4  Ecuador    Defender      Robert Arboleda   31    33      2
# 4      5  Ecuador  Midfielder       José Cifuentes   23    11      0
# ..   ...      ...         ...                  ...  ...   ...    ...
# 826  827  Uruguay    Defender       Martín Cáceres   35   115      4
# 827  828  Uruguay  Goalkeeper        Sergio Rochet   29     8      0
# 828  829  Uruguay  Midfielder     Agustín Canobbio   24     3      0
# 829  830  Uruguay  Midfielder        Manuel Ugarte   21     6      0
# 830  831  Uruguay    Defender  José Luis Rodríguez   25     0      0
#
#      WC Goals         League                  Club
# 0           0        Ecuador                 Aucas
# ...

# %%
# ARCHIVO: _2022_world_cup_matches

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\_2022_world_cup_matches.csv', sep=',', header=0)
df
# Out:
#     ID  Year        Date           Stage      Home Team    Away Team Host Team
# 0    1  2022  2022-11-20     Group stage          Qatar      Ecuador      True
# 1    2  2022  2022-11-21     Group stage        Senegal  Netherlands     False
# 2    3  2022  2022-11-21     Group stage        England         Iran     False
# 3    4  2022  2022-11-21     Group stage  United States        Wales     False
# 4    5  2022  2022-11-22     Group stage         France    Australia     False
# ..  ..   ...         ...             ...            ...          ...       ...
# 59  60  2022  2022-12-10  Quarter-finals            W55          W56       NaN
# 60  61  2022  2022-12-13     Semi-finals            W57          W58       NaN
# 61  62  2022  2022-12-14     Semi-finals            W59          W60       NaN
# 62  63  2022  2022-12-17     Third place            L61          L62       NaN
# 63  64  2022  2022-12-18           Final            W61          W62       NaN
#
# [64 rows x 7 columns]

# %%
# ARCHIVO: _2022_world_cup_groups

# %%
import pandas as pd
df= pd.read_csv('C:\MARTINEZ MARCELO\CURSOS\CURSO DE DATA SCIENCE\DATASETS\COPA DEL MUNDO\_2022_world_cup_groups.csv', sep=',', header=0)
df
# Out:
#    Group           Team  FIFA Ranking
# 0      A          Qatar            50
# 1      A        Ecuador            44
# 2      A        Senegal            18
# 3      A    Netherlands             8
# 4      B        England             5
# 5      B           Iran            20
# 6      B  United States            16
# 7      B          Wales            19
# 8      C      Argentina             3
# 9      C   Saudi Arabia            51
# 10     C         Mexico            13
# 11     C         Poland            26
# 12     D         France             4
# 13     D      Australia            38
# 14     D        Denmark            10
# 15     D        Tunisia            30
# 16     E          Spain             7
# 17     E     Costa Rica            31
# 18     E        Germany            11
# 19     E          Japan            24
# 20     F        Belgium             2
# 21     F         Canada            41
# 22     F        Morocco            22
# 23     F        Croatia            12
# ...
